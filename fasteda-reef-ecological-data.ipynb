# %% [markdown]
# ![image](https://storage.googleapis.com/kaggle-datasets-images/3623259/6298988/55af605eb4e9ea54a3d175214455f188/dataset-cover.jpg?t=2023-08-14-04-12-26)

# %% [markdown]
# # <div style="color:yellow;display:inline-block;border-radius:5px;background-color:#007BA7;font-family:Nexa;overflow:hidden"><p style="padding:15px;color:yellow;overflow:hidden;font-size:100%;letter-spacing:0.5px;margin:0"><b> </b>Introduction</p></div>
#
# Diving into the depths of Del Norte County's underwater wonders, the "Alacranes Reef and Bajos del Norte Reef Ecological Assessment" dataset unlocks a comprehensive exploration of these vibrant reef ecosystems. It unveils a meticulous evaluation dedicated to deciphering the intricacies of biodiversity, habitat vitality, and the dynamic pulse of life within these submerged realms.
#
# A symphony of data, carefully orchestrated through SCUBA-powered field surveys, forms the core of this dataset. It delivers a panoramic view, encompassing fish populations, biomass measurements, and the intricate tapestry of invertebrates and macroalgae coverage. Beyond unveiling the present state, these insights resonate with the underlying equilibrium and health of these reefs.
#
# In each dataset entry, a story unfolds: species abundance, biomass revelations, and the nuanced spread of invertebrates and macroalgae. Its significance extends as a lighthouse guiding researchers, ecologists, and policymakers through the labyrinthine corridors of aquatic ecology, conservation, and the ballet of interactions within these delicate marine environments.

# %% [markdown]
# # <div style="color:yellow;display:inline-block;border-radius:5px;background-color:#007BA7;font-family:Nexa;overflow:hidden"><p style="padding:15px;color:yellow;overflow:hidden;font-size:100%;letter-spacing:0.5px;margin:0"><b> </b> Import Modules</p></div>

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px
import plotly.graph_objects as go

plt.rcParams['figure.figsize'] = (12,6)
plt.style.use('fivethirtyeight')

import warnings
warnings.filterwarnings("ignore")

# %%
# %%capture
# %pip install fasteda

# %% [markdown]
# # <div style="color:yellow;display:inline-block;border-radius:5px;background-color:#007BA7;font-family:Nexa;overflow:hidden"><p style="padding:15px;color:yellow;overflow:hidden;font-size:100%;letter-spacing:0.5px;margin:0"><b> </b>Load the dataset</p></div>

# %%
# Load the dataset `into` a Pandas DataFrame
fish_df = pd.read_csv('/kaggle/input/reef-ecological-assessment-del-norte/Alacranes Reef and Bajos del Norte reef ecological assesment/fish_data.csv')
algae_df = pd.read_csv('/kaggle/input/reef-ecological-assessment-del-norte/Alacranes Reef and Bajos del Norte reef ecological assesment/invertebrate_algae_data.csv')

# %% [markdown]
# # <div style="color:yellow;display:inline-block;border-radius:5px;background-color:#007BA7;font-family:Nexa;overflow:hidden"><p style="padding:15px;color:yellow;overflow:hidden;font-size:100%;letter-spacing:0.5px;margin:0"><b> </b>Fast Exploratory Data Analysis</p></div>
#
# * fish_data.csv
# * invertebrate_algae_data.csv

# %%
from fasteda import fast_eda
fast_eda(fish_df)
# Out:
# DataFrame Head:
#   label  year  month  day          region              island      side  \
# 0   PEC  2019      8   10  Bajo del Norte     Bajos del Norte     Bajos
# 1   PEC  2019      8    9       Alacranes  Arrecife Alacranes  Windward
# 2   PEC  2019      8   11  Bajo del Norte     Bajos del Norte     Bajos
#
#    id_reef               reef  reef_joined protection_status   latitude  \
# 0       11  Bajos del norte 2            7                OA  23.242433
# 1        9        Tata y Rafa            3               MPA  22.553851
# 2       15              Final           10                OA  23.171183
#
#    longitude habitat  transect  area    phylum       taxa1           taxa2  \
# 0 -88.714417   Coral         2    60  Chordata  Vertebrata  Actinopterygii
# 1 -89.653701   Coral         6    60  Chordata  Vertebrata  Actinopterygii
# 2 -88.951301   Coral         3    60  Chordata  Vertebrata  Actinopterygii
#
# ...

# %%
from fasteda import fast_eda
fast_eda(algae_df)
# Out:
# DataFrame Head:
#   label  year  month  day     region              island     side        reef  \
# 0   ALG  2019      8    7  Alacranes  Arrecife Alacranes  Leeward  Cordillera
# 1   ALG  2019      8    7  Alacranes  Arrecife Alacranes  Leeward  Cordillera
# 2   ALG  2019      8    7  Alacranes  Arrecife Alacranes  Leeward  Cordillera
#
#    reef_joined protection_status  latitude  longitude habitat  transect  \
# 0            1               NTZ  22.39575 -89.706083   Coral         1
# 1            1               NTZ  22.39575 -89.706083   Coral         1
# 2            1               NTZ  22.39575 -89.706083   Coral         1
#
#        phylum            taxa1              taxa2         taxa3  \
# 0  Ochrophyta     Phaeophyceae   Dictyotophycidae   Dictyotales
# 1  Ochrophyta     Phaeophyceae   Dictyotophycidae   Dictyotales
# 2  Rhodophyta  Florideophyceae  Corallinophycidae  Corallinales
#
#      functional_group              species  quantity
# ...

# %% [markdown]
# <div class="alert alert-block alert-info"> 📌 "Hey there! Your positive feedback and support for my notebook mean the world to me! It motivates me to create more valuable content. If you can spare a moment to give it an upvote, it would help others discover and benefit from it too. Together, let's foster a vibrant community of knowledge-sharing and empowerment. Thank you for considering it, and continued success on your learning journey!"😊</div>
