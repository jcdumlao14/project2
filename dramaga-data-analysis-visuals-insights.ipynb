# %% [markdown]
# ![image](https://storage.googleapis.com/kaggle-datasets-images/3656549/6349617/09af75526fbac6642ca2767891aec3d4/dataset-cover.jpeg?t=2023-08-23-04-24-35)

# %% [markdown]
# # <div style="color:blue;display:inline-block;border-radius:5px;background-color:#50C878;font-family:Nexa;overflow:hidden"><p style="padding:15px;color:blue;overflow:hidden;font-size:100%;letter-spacing:0.5px;margin:0"><b></b>Introduction</p></div>
#
# In the context of the Dramaga region, this analysis delves into valuable insights and trends derived from data exploration. The attached visuals, encompassing graphs, figures, and statistical outcomes, offer a comprehensive understanding of the data's narrative. By closely examining these representations, we uncover essential patterns and correlations that provide a foundation for informed decision-making

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/visitor-willingness-to-pay-at-dramaga-forest/7rmz4ywsvm-1/Single bounded dichotomous-choice elicitation structure.png
# /kaggle/input/visitor-willingness-to-pay-at-dramaga-forest/7rmz4ywsvm-1/Number of visitors to Dramaga Research Forest.png
# /kaggle/input/visitor-willingness-to-pay-at-dramaga-forest/7rmz4ywsvm-1/WTP visitor supply curve.png
# /kaggle/input/visitor-willingness-to-pay-at-dramaga-forest/7rmz4ywsvm-1/WTP calculation using logit model.png
# /kaggle/input/visitor-willingness-to-pay-at-dramaga-forest/7rmz4ywsvm-1/WTP value through turnbull method.png
# /kaggle/input/visitor-willingness-to-pay-at-dramaga-forest/7rmz4ywsvm-1/The results of the elicitation structure of the single-bounded DC-CVM.png
# /kaggle/input/visitor-willingness-to-pay-at-dramaga-forest/7rmz4ywsvm-1/WTP value through logit model.png
# /kaggle/input/visitor-willingness-to-pay-at-dramaga-forest/7rmz4ywsvm-1/The results of logistic regression.png

# %% [markdown]
# # <div style="color:blue;display:inline-block;border-radius:5px;background-color:#50C878;font-family:Nexa;overflow:hidden"><p style="padding:15px;color:blue;overflow:hidden;font-size:85%;letter-spacing:0.5px;margin:0"><b></b>Graphs and Figures</p></div>
#
# * Display key graphs and figures from the manuscript.
# * Interpret the visual representation of data trends and patterns.
#
# #### Interpretation of Visual Representation of Data Trends and Patterns:
#
# The attached graphs and figures shed light on the dynamics within the Dramaga region. These visuals serve as windows into the data's story, revealing trends and patterns that might not be immediately evident from raw numbers. By carefully analyzing the trajectories displayed in these visuals, we can discern seasonality, growth trends, and potential outliers that offer insights into visitor preferences, attendance patterns, and more.

# %% [markdown]
# # <div style="color:blue;display:inline-block;border-radius:5px;background-color:#50C878;font-family:Nexa;overflow:hidden"><p style="padding:15px;color:blue;overflow:hidden;font-size:70%;letter-spacing:0.5px;margin:0"><b></b>Number of visitors to Dramaga Research Forest</p></div>

# %%
from IPython.display import Image, display
from PIL import Image as PILImage
import os

# List of image files
image_files = [
    "/kaggle/input/visitor-willingness-to-pay-at-dramaga-forest/7rmz4ywsvm-1/Number of visitors to Dramaga Research Forest.png"
]

# Create the directory for saving images if it doesn't exist
save_directory = "saved_images"
os.makedirs(save_directory, exist_ok=True)

for image_file in image_files:
    img = PILImage.open(image_file)
    img = img.resize((500, 300))  # Resize the image if desired
    display(img)

    # Save the image
    save_path = os.path.join(save_directory, image_file.split("/")[-1])
    img.save(save_path)
    #print(f"Image saved as: {save_path}")

    #print("\n---\n")
# Out:
# <PIL.Image.Image image mode=P size=500x300>

# %% [markdown]
# # <div style="color:blue;display:inline-block;border-radius:5px;background-color:#50C878;font-family:Nexa;overflow:hidden"><p style="padding:15px;color:blue;overflow:hidden;font-size:70%;letter-spacing:0.5px;margin:0"><b></b>Single bounded dichotomous-choice elicitation structure</p></div>

# %%
# List of image files
image_files = [
    "/kaggle/input/visitor-willingness-to-pay-at-dramaga-forest/7rmz4ywsvm-1/Single bounded dichotomous-choice elicitation structure.png"
]

# Create the directory for saving images if it doesn't exist
save_directory = "saved_images"
os.makedirs(save_directory, exist_ok=True)

for image_file in image_files:
    img = PILImage.open(image_file)
    img = img.resize((500, 300))  # Resize the image if desired
    display(img)

    # Save the image
    save_path = os.path.join(save_directory, image_file.split("/")[-1])
    img.save(save_path)
# Out:
# <PIL.Image.Image image mode=RGBA size=500x300>

# %% [markdown]
# # <div style="color:blue;display:inline-block;border-radius:5px;background-color:#50C878;font-family:Nexa;overflow:hidden"><p style="padding:15px;color:blue;overflow:hidden;font-size:80%;letter-spacing:0.5px;margin:0"><b></b>The results of logistic regression</p></div>

# %%
# List of image files
image_files = [
    "/kaggle/input/visitor-willingness-to-pay-at-dramaga-forest/7rmz4ywsvm-1/The results of logistic regression.png"
]

# Create the directory for saving images if it doesn't exist
save_directory = "saved_images"
os.makedirs(save_directory, exist_ok=True)

for image_file in image_files:
    img = PILImage.open(image_file)
    img = img.resize((500, 600))  # Resize the image if desired
    display(img)

    # Save the image
    save_path = os.path.join(save_directory, image_file.split("/")[-1])
    img.save(save_path)
# Out:
# <PIL.Image.Image image mode=RGBA size=500x600>

# %% [markdown]
# # <div style="color:blue;display:inline-block;border-radius:5px;background-color:#50C878;font-family:Nexa;overflow:hidden"><p style="padding:15px;color:blue;overflow:hidden;font-size:60%;letter-spacing:0.5px;margin:0"><b></b>Elicitation structure of the single-bounded DC-CVM</p></div>

# %%
# List of image files
image_files = [
    "/kaggle/input/visitor-willingness-to-pay-at-dramaga-forest/7rmz4ywsvm-1/The results of the elicitation structure of the single-bounded DC-CVM.png"
]

# Create the directory for saving images if it doesn't exist
save_directory = "saved_images"
os.makedirs(save_directory, exist_ok=True)

for image_file in image_files:
    img = PILImage.open(image_file)
    img = img.resize((500, 300))  # Resize the image if desired
    display(img)

    # Save the image
    save_path = os.path.join(save_directory, image_file.split("/")[-1])
    img.save(save_path)
# Out:
# <PIL.Image.Image image mode=RGBA size=500x300>

# %% [markdown]
# # <div style="color:blue;display:inline-block;border-radius:5px;background-color:#50C878;font-family:Nexa;overflow:hidden"><p style="padding:15px;color:blue;overflow:hidden;font-size:70%;letter-spacing:0.5px;margin:0"><b></b>WTP calculation using logit model</p></div>

# %%
# List of image files
image_files = [
    "/kaggle/input/visitor-willingness-to-pay-at-dramaga-forest/7rmz4ywsvm-1/WTP calculation using logit model.png"
]

# Create the directory for saving images if it doesn't exist
save_directory = "saved_images"
os.makedirs(save_directory, exist_ok=True)

for image_file in image_files:
    img = PILImage.open(image_file)
    img = img.resize((500, 300))  # Resize the image if desired
    display(img)

    # Save the image
    save_path = os.path.join(save_directory, image_file.split("/")[-1])
    img.save(save_path)
# Out:
# <PIL.Image.Image image mode=RGBA size=500x300>

# %% [markdown]
# # <div style="color:blue;display:inline-block;border-radius:5px;background-color:#50C878;font-family:Nexa;overflow:hidden"><p style="padding:15px;color:blue;overflow:hidden;font-size:80%;letter-spacing:0.5px;margin:0"><b></b>WTP value through logit model</p></div>

# %%
# List of image files
image_files = [
    "/kaggle/input/visitor-willingness-to-pay-at-dramaga-forest/7rmz4ywsvm-1/WTP value through logit model.png"
]

# Create the directory for saving images if it doesn't exist
save_directory = "saved_images"
os.makedirs(save_directory, exist_ok=True)

for image_file in image_files:
    img = PILImage.open(image_file)
    img = img.resize((500, 400))  # Resize the image if desired
    display(img)

    # Save the image
    save_path = os.path.join(save_directory, image_file.split("/")[-1])
    img.save(save_path)
# Out:
# <PIL.Image.Image image mode=RGBA size=500x400>

# %% [markdown]
# # <div style="color:blue;display:inline-block;border-radius:5px;background-color:#50C878;font-family:Nexa;overflow:hidden"><p style="padding:15px;color:blue;overflow:hidden;font-size:80%;letter-spacing:0.5px;margin:0"><b></b>WTP value through turnbull method</p></div>

# %%
# List of image files
image_files = [
    "/kaggle/input/visitor-willingness-to-pay-at-dramaga-forest/7rmz4ywsvm-1/WTP value through turnbull method.png"
]

# Create the directory for saving images if it doesn't exist
save_directory = "saved_images"
os.makedirs(save_directory, exist_ok=True)

for image_file in image_files:
    img = PILImage.open(image_file)
    img = img.resize((500, 400))  # Resize the image if desired
    display(img)

    # Save the image
    save_path = os.path.join(save_directory, image_file.split("/")[-1])
    img.save(save_path)
# Out:
# <PIL.Image.Image image mode=RGBA size=500x400>

# %% [markdown]
# # <div style="color:blue;display:inline-block;border-radius:5px;background-color:#50C878;font-family:Nexa;overflow:hidden"><p style="padding:15px;color:blue;overflow:hidden;font-size:80%;letter-spacing:0.5px;margin:0"><b></b>WTP visitor supply curve</p></div>

# %%
from IPython.display import Image, display
from PIL import Image as PILImage
import os

# List of image files
image_files = [
    "/kaggle/input/visitor-willingness-to-pay-at-dramaga-forest/7rmz4ywsvm-1/WTP visitor supply curve.png"
]

# Create the directory for saving images if it doesn't exist
save_directory = "saved_images"
os.makedirs(save_directory, exist_ok=True)

for image_file in image_files:
    img = PILImage.open(image_file)
    img = img.resize((500, 300))  # Resize the image if desired
    display(img)

    # Save the image
    save_path = os.path.join(save_directory, image_file.split("/")[-1])
    img.save(save_path)
    #print(f"Image saved as: {save_path}")

    #print("\n---\n")
# Out:
# <PIL.Image.Image image mode=P size=500x300>
