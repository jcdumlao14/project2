# %% [markdown]
# # <div style="color:blue;display:inline-block;border-radius:5px;background-color:#F0E68C;font-family:Nexa;overflow:hidden"><p style="padding:20px;color:blue;overflow:hidden;font-size:90%;letter-spacing:0.5px;margin:0"><b> </b>Dataset Overview</p></div>
#
#
#
# #### 🔘 Number of observations (N): 5
# #### 🔘 Columns (Variables):
# #### 🔘 Sub (Subject)
# #### 🔘 Birth (Year of Birth)
# #### 🔘 Age (Current Age)
# #### 🔘 Sex (Gender)
# #### 🔘 Task
# #### 🔘 Practice
# #### 🔘 prePSS (Pre-Perceived Stress Scale)
# #### 🔘 postPSS (Post-Perceived Stress Scale)
# #### 🔘 MAIA (Multidimensional Assessment of Interoceptive Awareness) sub-scales: Noticing, Body listening, Trusting, N-Distracting, N-Worrying, Attention Regulation, Emotional Awareness, Self-regulation.

# %% [markdown]
# # <div style="color:blue;display:inline-block;border-radius:5px;background-color:#F0E68C;font-family:Nexa;overflow:hidden"><p style="padding:20px;color:blue;overflow:hidden;font-size:90%;letter-spacing:0.5px;margin:0"><b> </b> Import Modules</p></div>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

import time

rc = {
    "axes.facecolor": "#E6FFE6",
    "figure.facecolor": "#E6FFE6",
    "axes.edgecolor": "#000000",
    "grid.color": "#EBEBE7",
    "font.family": "serif",
    "axes.labelcolor": "#000000",
    "xtick.color": "#000000",
    "ytick.color": "#000000",
    "grid.alpha": 0.4
}

sns.set(rc=rc)

from colorama import Style, Fore
red = Style.BRIGHT + Fore.RED
blu = Style.BRIGHT + Fore.BLUE
mgt = Style.BRIGHT + Fore.MAGENTA
gld = Style.BRIGHT + Fore.YELLOW
res = Style.RESET_ALL

# %% [markdown]
# # <div style="color:blue;display:inline-block;border-radius:5px;background-color:#F0E68C;font-family:Nexa;overflow:hidden"><p style="padding:20px;color:blue;overflow:hidden;font-size:90%;letter-spacing:0.5px;margin:0"><b> </b>Load the Dataset</p></div>

# %%
# Read the Excel file
data = pd.read_excel('/kaggle/input/interoception-study-self-brushing-vs-mindfulness/Data for The role of self body brushing vs mindfulness meditation on interoceptive awareness a non-randomized pilot study on healthy participants with possible implications for body image disturbances/Data.xlsx')
data.head().style.set_properties(**{'background-color':'royalblue','color':'white','border-color':'#8b8c8c'})
# Out:
# <style type="text/css">
# ...

# %%
# Define the mapping of old column names to new column names
column_mapping = {
    'Unnamed: 0': 'N',
    'Unnamed: 1': 'Sub',
    'Unnamed: 2': 'Birth',
    'Unnamed: 3': 'Age',
    'Unnamed: 4': 'Sex',
    'Unnamed: 5': 'Task',
    'Unnamed: 6': 'Practice',
    '1-pre': 'prePSS',
    '2-post': 'postPSS',
    '1-pre.1': 'MAIA Noticing',
    '1-pre.2': 'MAIA N-Distracting',
    '1-pre.3': 'MAIA N-Worrying',
    '1-pre.4': 'MAIA Attention Reg.',
    '1-pre.5': 'MAIA Emotional Aw.',
    '1-pre.6': 'MAIA Self-regulation',
    '1-pre.7': 'MAIA Body listening',
    '1-pre.8': 'MAIA Trusting',
    '2-post.1': 'MAIA Noticing',
    '2-post.2': 'MAIA N-Distracting',
    '2-post.3': 'MAIA N-Worrying',
    '2-post.4': 'MAIA Attention Reg.',
    '2-post.5': 'MAIA Emotional Aw.',
    '2-post.6': 'MAIA Self-regulation',
    '2-post.7': 'MAIA Body listening',
    '2-post.8': 'MAIA Trusting'
}

# Rename the columns
df = data.rename(columns=column_mapping)

# Save the DataFrame with the new column names
df.to_csv('new_dataset.csv', index=False)  # Change the file name if needed

# %%
df.head()
# Out:
#    N  Sub  Birth  Age  Sex  Task  Practice prePSS postPSS  MAIA Noticing  ...  \
# 0  N  Sub  Birth  Age  Sex  Task  Practice    PSS     PSS  MAIA Noticing  ...
# 1  1   s1   1994   23    M   SBS        50     23      17              4  ...
# 2  2   s2   1963   54    F   SBS       140     12      12              4  ...
# 3  3   s3   1958   59    F   SBS        75      7       8           2.25  ...
# 4  4   s4   1991   26    F   SBS        75     20      17              4  ...
#
#    MAIA Body listening  MAIA Trusting  MAIA Noticing  MAIA N-Distracting  \
# 0  MAIA Body listening  MAIA Trusting  MAIA Noticing  MAIA N-Distracting
# 1                    2              3            4.5            2.333333
# 2             3.333333              4           4.25            2.333333
# 3                    2       4.666667           3.25            0.666667
# 4             1.333333       2.333333           3.75            3.666667
#
# ...

# %%
# Remove the first row
df = df.iloc[1:]

# Reset the index after removing the row
df = df.reset_index(drop=True)

df.head()
# Out:
#    N Sub Birth Age Sex Task Practice prePSS postPSS MAIA Noticing  ...  \
# 0  1  s1  1994  23   M  SBS       50     23      17             4  ...
# 1  2  s2  1963  54   F  SBS      140     12      12             4  ...
# 2  3  s3  1958  59   F  SBS       75      7       8          2.25  ...
# 3  4  s4  1991  26   F  SBS       75     20      17             4  ...
# 4  5  s5  1990  27   F  SBS      110     19      20          2.25  ...
#
#   MAIA Body listening MAIA Trusting MAIA Noticing MAIA N-Distracting  \
# 0                   2             3           4.5           2.333333
# 1            3.333333             4          4.25           2.333333
# 2                   2      4.666667          3.25           0.666667
# 3            1.333333      2.333333          3.75           3.666667
# 4                   1      2.333333          3.25                  2
#
#   MAIA N-Worrying MAIA Attention Reg. MAIA Emotional Aw. MAIA Self-regulation  \
# ...

# %% [markdown]
# # <div style="color:blue;display:inline-block;border-radius:5px;background-color:#F0E68C;font-family:Nexa;overflow:hidden"><p style="padding:20px;color:blue;overflow:hidden;font-size:90%;letter-spacing:0.5px;margin:0"><b> </b>Subject Information</p></div>
#
#
#
# #### 🔘 Subjects: s1, s2, s3, s4, s5
# #### 🔘 Birth years: 1994, 1963, 1958, 1991, 1990
# #### 🔘 Current ages: 23, 54, 59, 26, 27
# #### 🔘 Gender distribution: 4 Female, 1 Male

# %%
# Subject Information
subject_info = df[['Sub', 'Birth', 'Age', 'Sex']]
subject_info.head(10).style.set_properties(**{'background-color':'green','color':'white','border-color':'#8b8c8c'})
# Out:
# <style type="text/css">
# #T_951ba_row0_col0, #T_951ba_row0_col1, #T_951ba_row0_col2, #T_951ba_row0_col3, #T_951ba_row1_col0, #T_951ba_row1_col1, #T_951ba_row1_col2, #T_951ba_row1_col3, #T_951ba_row2_col0, #T_951ba_row2_col1, #T_951ba_row2_col2, #T_951ba_row2_col3, #T_951ba_row3_col0, #T_951ba_row3_col1, #T_951ba_row3_col2, #T_951ba_row3_col3, #T_951ba_row4_col0, #T_951ba_row4_col1, #T_951ba_row4_col2, #T_951ba_row4_col3, #T_951ba_row5_col0, #T_951ba_row5_col1, #T_951ba_row5_col2, #T_951ba_row5_col3, #T_951ba_row6_col0, #T_951ba_row6_col1, #T_951ba_row6_col2, #T_951ba_row6_col3, #T_951ba_row7_col0, #T_951ba_row7_col1, #T_951ba_row7_col2, #T_951ba_row7_col3, #T_951ba_row8_col0, #T_951ba_row8_col1, #T_951ba_row8_col2, #T_951ba_row8_col3, #T_951ba_row9_col0, #T_951ba_row9_col1, #T_951ba_row9_col2, #T_951ba_row9_col3 {
#   background-color: green;
#   color: white;
#   border-color: #8b8c8c;
# }
# </style>
# <table id="T_951ba">
#   <thead>
#     <tr>
# ...

# %% [markdown]
# # <div style="color:blue;display:inline-block;border-radius:5px;background-color:#F0E68C;font-family:Nexa;overflow:hidden"><p style="padding:20px;color:blue;overflow:hidden;font-size:90%;letter-spacing:0.5px;margin:0"><b> </b>Task and Practice Information</p></div>
#
# #### 🔘 Task: SBS (Assuming it stands for something related to the study)
# #### 🔘 Practice duration (in minutes)

# %%
# Task and Practice Information
task_info = df[['Task', 'Practice']]
task_info.head(10).style.set_properties(**{'background-color':'red','color':'white','border-color':'#8b8c8c'})
# Out:
# <style type="text/css">
# #T_bfedb_row0_col0, #T_bfedb_row0_col1, #T_bfedb_row1_col0, #T_bfedb_row1_col1, #T_bfedb_row2_col0, #T_bfedb_row2_col1, #T_bfedb_row3_col0, #T_bfedb_row3_col1, #T_bfedb_row4_col0, #T_bfedb_row4_col1, #T_bfedb_row5_col0, #T_bfedb_row5_col1, #T_bfedb_row6_col0, #T_bfedb_row6_col1, #T_bfedb_row7_col0, #T_bfedb_row7_col1, #T_bfedb_row8_col0, #T_bfedb_row8_col1, #T_bfedb_row9_col0, #T_bfedb_row9_col1 {
#   background-color: red;
#   color: white;
#   border-color: #8b8c8c;
# }
# </style>
# <table id="T_bfedb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bfedb_level0_col0" class="col_heading level0 col0" >Task</th>
#       <th id="T_bfedb_level0_col1" class="col_heading level0 col1" >Practice</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bfedb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bfedb_row0_col0" class="data row0 col0" >SBS</td>
# ...

# %% [markdown]
# # <div style="color:blue;display:inline-block;border-radius:5px;background-color:#F0E68C;font-family:Nexa;overflow:hidden"><p style="padding:20px;color:blue;overflow:hidden;font-size:90%;letter-spacing:0.5px;margin:0"><b> </b>Pre and Post Perceived Stress Scale (PSS)</p></div>
#
# #### 🔘 Pre-PSS scores: Range from 50 to 140
# #### 🔘 Post-PSS scores: Range from 7 to 23

# %%
# Pre and Post PSS
pss_info = df[['prePSS', 'postPSS']]
pss_info.head(10).style.set_properties(**{'background-color':'orange','color':'white','border-color':'#8b8c8c'})
# Out:
# <style type="text/css">
# #T_a12ed_row0_col0, #T_a12ed_row0_col1, #T_a12ed_row1_col0, #T_a12ed_row1_col1, #T_a12ed_row2_col0, #T_a12ed_row2_col1, #T_a12ed_row3_col0, #T_a12ed_row3_col1, #T_a12ed_row4_col0, #T_a12ed_row4_col1, #T_a12ed_row5_col0, #T_a12ed_row5_col1, #T_a12ed_row6_col0, #T_a12ed_row6_col1, #T_a12ed_row7_col0, #T_a12ed_row7_col1, #T_a12ed_row8_col0, #T_a12ed_row8_col1, #T_a12ed_row9_col0, #T_a12ed_row9_col1 {
#   background-color: orange;
#   color: white;
#   border-color: #8b8c8c;
# }
# </style>
# <table id="T_a12ed">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a12ed_level0_col0" class="col_heading level0 col0" >prePSS</th>
#       <th id="T_a12ed_level0_col1" class="col_heading level0 col1" >postPSS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a12ed_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a12ed_row0_col0" class="data row0 col0" >23</td>
# ...

# %% [markdown]
# # <div style="color:blue;display:inline-block;border-radius:5px;background-color:#F0E68C;font-family:Nexa;overflow:hidden"><p style="padding:20px;color:blue;overflow:hidden;font-size:90%;letter-spacing:0.5px;margin:0"><b> </b>MAIA Sub-Scales</p></div>
#
# #### 🔘 Noticing, Body Listening, Trusting, N-Distracting, N-Worrying, Attention Regulation, Emotional Awareness, Self-regulation
# #### 🔘 Each sub-scale has corresponding scores for each subject.

# %%
# MAIA Sub-Scales
maia_scales = df.iloc[:, 8:]
maia_scales.head(10)
# Out:
#   postPSS MAIA Noticing MAIA N-Distracting MAIA N-Worrying  \
# 0      17             4                  1        3.333333
# 1      12             4           2.333333        2.666667
# 2       8          2.25                  1        1.333333
# 3      17             4           2.666667               2
# 4      20          2.25                  2               3
# 5      15           0.5           1.333333               4
# 6      23             3           1.333333               2
# 7      16          2.25           2.333333               2
# 8      22          3.75                  2               2
# 9       9             5           2.333333        1.666667
#
#   MAIA Attention Reg. MAIA Emotional Aw. MAIA Self-regulation  \
# 0            2.857143                  4                 3.75
# 1            2.857143                4.2                  3.5
# 2            3.428571                3.8                 2.75
# 3            1.142857                2.2                 1.25
# ...

# %% [markdown]
# # <div style="color:blue;display:inline-block;border-radius:5px;background-color:#F0E68C;font-family:Nexa;overflow:hidden"><p style="padding:20px;color:blue;overflow:hidden;font-size:90%;letter-spacing:0.5px;margin:0"><b> </b>Summary Statistics</p></div>
#
# #### 🔘 Depending on the purpose of the analysis, you may want to calculate summary statistics like mean, median, standard deviation, etc., for each variable.

# %%
# Summary Statistics 
summary_stats = df.describe()
summary_stats.head()
# Out:
#          N Sub  Birth  Age Sex Task Practice  prePSS  postPSS  MAIA Noticing  \
# count   42  42     42   42  42   42       42      42       42             42
# unique  15  42     28   27   2    3       23      20       19             15
# top      1  s1   1980   27   F  MOM        -       9       18              3
# freq     3   1      5    4  34   15       14       6        5              6
#
#         ...  MAIA Body listening  MAIA Trusting  MAIA Noticing  \
# count   ...                   42             42             42
# unique  ...                   13             13             15
# top     ...                    2              5              4
# freq    ...                    9              8              7
#
#         MAIA N-Distracting  MAIA N-Worrying  MAIA Attention Reg.  \
# count                   42        42.000000            42.000000
# unique                  11        12.000000            18.000000
# ...

# %% [markdown]
# # <div style="color:blue;display:inline-block;border-radius:5px;background-color:#F0E68C;font-family:Nexa;overflow:hidden"><p style="padding:20px;color:blue;overflow:hidden;font-size:90%;letter-spacing:0.5px;margin:0"><b> </b>Data Exploration</p></div>
#
# #### 🔘 Visualizations or descriptive statistics to get a sense of the distribution of variables.

# %%
# Visualizing Age Distribution
sns.histplot(df['Age'], kde=True)
plt.title('Age Distribution', fontsize = 14, fontweight = 'bold', color = 'darkblue')
plt.savefig('Age Distribution.png')
plt.show()

# %% [markdown]
# #### 🔘 Correlation analysis between variables.

# %%
# Correlation between prePSS and postPSS

# Check Data Types
print(df.dtypes[['prePSS', 'postPSS']])
# Out:
# prePSS     object
# postPSS    object
# dtype: object

# %%
# Check for Missing Values
print(df[['prePSS', 'postPSS']].isnull().sum())
# Out:
# prePSS     0
# postPSS    0
# dtype: int64

# %%
# Check Unique Values (Optional)
print(df[['prePSS', 'postPSS']].nunique())
# Out:
# prePSS     20
# postPSS    19
# dtype: int64

# %%
# Ensure Numeric Values
df[['prePSS', 'postPSS']] = df[['prePSS', 'postPSS']].apply(pd.to_numeric, errors='coerce')

# Check Data Types Again
print(df.dtypes[['prePSS', 'postPSS']])
# Out:
# prePSS     int64
# postPSS    int64
# dtype: object

# %%
# Calculate Correlation
correlation = df['prePSS'].corr(df['postPSS'])
print(f'Correlation between prePSS and postPSS: {correlation:.2f}')

# Create a scatter plot
plt.figure(figsize=(8, 6))
sns.scatterplot(x='prePSS', y='postPSS', data=df)
plt.title('Scatter Plot of prePSS vs. postPSS', fontsize = 14, fontweight = 'bold', color = 'darkblue')
plt.xlabel('prePSS', fontsize = 12, fontweight = 'bold', color = 'darkgreen')
plt.ylabel('postPSS', fontsize = 12, fontweight = 'bold', color = 'darkgreen')
plt.savefig('Scatter Plot of prePSS vs. postPSS.png')
plt.show()
# Out:
# Correlation between prePSS and postPSS: 0.51

# %% [markdown]
# #### 🔘 Comparisons between Different Groups (e.g., Gender Differences):

# %%
# Comparisons between genders
plt.figure(figsize=(8, 6))
sns.boxplot(x='Sex', y='prePSS', data=df)
plt.title('Pre-PSS by Gender', fontsize = 14, fontweight = 'bold', color = 'darkblue')
plt.xlabel('Gender', fontsize = 12, fontweight = 'bold', color = 'darkgreen')
plt.ylabel('Pre-PSS', fontsize = 12, fontweight = 'bold', color = 'darkgreen')
plt.savefig('Pre-PSS by Gender.png')
plt.show()

# %% [markdown]
# # <div style="color:blue;display:inline-block;border-radius:5px;background-color:#F0E68C;font-family:Nexa;overflow:hidden"><p style="padding:20px;color:blue;overflow:hidden;font-size:90%;letter-spacing:0.5px;margin:0"><b> </b>Regression Analysis</p></div>
#
# #### let's predict 'postPSS' based on 'prePSS'.

# %%
import statsmodels.api as sm

# Adding a constant for the intercept
X = sm.add_constant(df['prePSS'])
y = df['postPSS']

# Fit the regression model
model = sm.OLS(y, X).fit()

# Print the regression results
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                postPSS   R-squared:                       0.255
# Model:                            OLS   Adj. R-squared:                  0.237
# Method:                 Least Squares   F-statistic:                     13.71
# Date:                Thu, 07 Sep 2023   Prob (F-statistic):           0.000644
# Time:                        08:44:06   Log-Likelihood:                -121.75
# No. Observations:                  42   AIC:                             247.5
# Df Residuals:                      40   BIC:                             251.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          8.2635      1.948      4.243      0.000       4.327      12.200
# ...

# %% [markdown]
# <div class="alert alert-block alert-info"> 📌 "If you have some time to spare, I invite you all,  to explore it further and consider creating a notebook based on your insights and analysis. Your contributions could offer valuable perspectives to our community. If you find the dataset interesting and your experience positive, your upvote would be greatly appreciated. Your support encourages further collaboration and knowledge sharing. Thank you for considering this opportunity!"😊 </div>
